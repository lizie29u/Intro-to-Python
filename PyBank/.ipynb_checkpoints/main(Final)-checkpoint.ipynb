# %%
from pathlib import Path
import csv

# Check the current directory where the Python program is executing from
#print(f"Current Working Directory: {Path.cwd()}")

# Set the input file path 
csvpath = Path("Resources/budget_data.csv")

profit_loss_list = []

# Open the csv file as an object
with open(csvpath, "r") as csvfile:

    csvreader = csv.reader(csvfile, delimiter=",")
    csv_header = next(csvreader)
    prev_row = next(csvreader)
    
    # Print the header
    #print(csv_header)

    #print(prev_row)
    
   #Initialize variables

    Total_num_months=1
    prev_value=int(prev_row[1])
    profit_loss_list.append(prev_value)
    max_changes = 0
    min_changes = 0
    
   # Initialize metric variables
    max_changes = 0
    min_changes = 0
 
    #print(prev_value)
    
    change_list =[]   
    
    date_list =[]   
    
  
    # Read each row of data after the header
    for row in csvreader:
        # Print the row
        #print(row)
        
     #The total number of months included in the dataset.  
       
        Total_num_months +=1    
        month = row[0]
        Profit_Loss = int(row[1])
        profit_loss_list.append(Profit_Loss)
        date = month
        changes= Profit_Loss-prev_value
        change_list.append(changes)
        prev_value= Profit_Loss
        date_list.append(date)
        
        
          # Logic to determine min and max changes
        if min_changes == 0:
            min_changes = changes
        elif changes > max_changes:
            max_changes = changes
        elif changes < min_changes:
            min_changes= changes
        

#The net total amount of Profit/Losses over the entire period.        
x=(sum(profit_loss_list)) 

#Total of the changes over the months
c=(sum(change_list)) 

#he average of the changes in Profit/Losses over the entire period.
a=(round(c/((Total_num_months)-1),2))



# Initialize metric variables
# max_changes = 0
# min_changes = 0

#T  
  

#print(Total_num_months)  

#Total Months: 86 
print(f"Total Months: {Total_num_months}" )

#print(profit_loss_list)

#The net total amount of Profit/Losses over the entire period.
#Total: $38382578
#print(x)
print(f"Total: ${x}")

#print(change_list)
#print(c)

#he average of the changes in Profit/Losses over the entire period.
#print(a)

#Average  Change: $-2315.12
print(f"Average  Change: ${a}")

#The greatest increase in profits over the entire perio
#print(max_changes)

#The greatest decrease in losses over the entire period.
#print(min_changes)
#print(date_list)


#find the index of the max change
#print(change_list.index(1926159))

#find the (max) month (for index 24)
#print(date_list[24])

#Greatest Increase in Profits: Feb-2012 ($1926159)
print(f"Greatest Increase in Profits:{date_list[24]} (${max_changes}) ")

#find the index of the min change
#print(change_list.index(-2196167))

#find the (min) month (for index 43)
#print(date_list[43])

# Greatest Decrease in Profits: Sep-2013 ($-2196167)
print(f"Greatest Decrease in Profits:{date_list[43]} (${min_changes}) ")

# print(line_num)  
#print(x)    
# print(change) 

    #The average of the changes in Profit/Losses over the entire period
# Out:
# Total Months: 86
# Total: $38382578
# Average  Change: $-2315.12
# Greatest Increase in Profits:Feb-2012 ($1926159)
# Greatest Decrease in Profits:Sep-2013 ($-2196167)
